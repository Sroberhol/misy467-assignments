# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv('housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (20640, 10)

# %% [markdown]
# ### Ocean_Proximity is a categorical column. The rest of the Columns are numerical columns.

# %% [markdown]
# ### Null values are different from empty cells. Null values are shown with NaN. Look for shape of dataframe, data types of columns, and whether or not there are null values.

# %%
#basic descriptive statistics for all numerical columns
df.describe(include='all')
#use df.describe(include='all') to see catagorical
# Out:
#            longitude      latitude  housing_median_age   total_rooms  \
# count   20640.000000  20640.000000        20640.000000  20640.000000
# unique           NaN           NaN                 NaN           NaN
# top              NaN           NaN                 NaN           NaN
# freq             NaN           NaN                 NaN           NaN
# mean     -119.569704     35.631861           28.639486   2635.763081
# std         2.003532      2.135952           12.585558   2181.615252
# min      -124.350000     32.540000            1.000000      2.000000
# 25%      -121.800000     33.930000           18.000000   1447.750000
# 50%      -118.490000     34.260000           29.000000   2127.000000
# 75%      -118.010000     37.710000           37.000000   3148.000000
# max      -114.310000     41.950000           52.000000  39320.000000
#
#         total_bedrooms    population    households  median_income  \
# count     20433.000000  20640.000000  20640.000000   20640.000000
# ...

# %%
# pandas uses bin 10 when creating a histogram.

# %% [markdown]
# ### When plotting a histogram, we are looking to find the distribution of data, center and spread, skewness, and presence of outliers.

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112909b70>,
# ...
#       dtype=object)

# %%
df['median_income'].hist(bins=50)

# %%
df['ocean_proximity'].hist()

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ##### Boxplot -> the box is the middle 50%. The outliers are the dots that are on the oustide of the two lines.

# %%
#creates an array of 10 numbers
x = np.linspace(0, 10, 10)
x
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
#adds two numbers, 20 and 22
x = np.append(x, [14, 22, 100])
x
# Out:
# array([  0.        ,   1.11111111,   2.22222222,   3.33333333,
#          4.44444444,   5.55555556,   6.66666667,   7.77777778,
#          8.88888889,  10.        ,  14.        ,  22.        ,
#        100.        ])

# %%
#changes the array into a DataFrame
x = pd.DataFrame(x)
x.head()
# Out:
#           0
# 0  0.000000
# 1  1.111111
# 2  2.222222
# 3  3.333333
# 4  4.444444

# %%
x.boxplot()

# %%
df['median_income'].plot.box()

# %%
df['housing_median_age'].plot.box()

# %%
fig, ax = plt.subplots(2, figsize=(10, 20))
ax[0].scatter(x=df['median_income'], y=df['median_house_value'], alpha = 0.2) # alpha=0.2 specifies the opacity
ax[0].set_xlabel('median income')
ax[0].set_ylabel('median house value')
ax[1].scatter(x=df['housing_median_age'], y=df['median_house_value'], alpha=0.2) # alpha=0.2 specifies the opacity
ax[1].set_xlabel('housing median age')
ax[1].set_ylabel('median house value')
# Out:
# Text(0, 0.5, 'median house value')
